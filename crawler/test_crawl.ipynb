# %%
import requests
import json
import sys

url = "https://api.proxyxoay.org/api/key_xoay.php?key=dfwDXxGTjeHVcLEIZVES&live=5"
response = requests.get(url)
print(response.text)
# Out:
# {"key":"dfwDXxGTjeHVcLEIZVES","time":300,"proxyhttp":"113.172.172.91:42921:tmproxyfTuDY:5oZyQ14fGR","proxysocks5":"113.172.172.91:42921:tmproxyfTuDY:5oZyQ14fGR","nha_mang":"VNPT","vi_tri":"TP Ho Chi Minh","time_die":880,"next_allowed_in_seconds":60,"next_allowed_at_timestamp":1768377982}

# %%
import json

file_path = "../data/full_lazada.ndjson"

with open(file_path, "r", encoding="utf-8") as f:
    for i in range(10):
        line = f.readline()
        if not line:
            break  # hết file
        data = json.loads(line)
        print(f"Object {i + 1}:")
        print(json.dumps(data, indent=4, ensure_ascii=False))
        print("-" * 40)
# Out:
# Object 1:
# {
#     "product_name": "[HCM]Mắt Kính Lão Gọng Kim Loại Siêu Rẽ",
#     "url": "https://www.lazada.vn/products/pdp-i508508763.html",
#     "rating_average": 4.7,
#     "reviews_count": 356,
# ...

# %%
variants.variant = attrs
"rating_average" - >avg_rating
reviews_count -> num_review
"sold"- > num_sold 
variants.price->  price
product_name -> product_name
non -> shipping
url -> url
non country
brand 
stock
origin (bỏ qua)
firstcategory
secondcategory
description
shopname

# %%
[
    {},
    {}
    
]

# %%
{},
{}

# %%
import json

file_path = "../data/combined_example.ndjson"

with open(file_path, "r", encoding="utf-8") as f:
    line = f.readline()          # đọc 1 dòng
    data = json.loads(line)      # parse NDJSON -> dict

# in JSON đẹp mắt
print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# {
#     "product_name": "Yêu Thích\nJumsuit Ngố Cúp Ngực Hở Lưng Kèm Mút - 25 Store",
#     "shipping": null,
#     "shop_info": "Yêu Thích\nkhochuyensi25store\nOnline 1 Phút Trước\nChat Ngay\nXem Shop\nĐánh Giá\n3,8k\nSản Phẩm\n358\nTỉ Lệ Phản Hồi\n71%\nThời Gian Phản Hồi\ntrong vài giờ\nTham Gia\n3 năm trước\nNgười Theo Dõi\n4,5k",
#     "price": "₫99.000",
# ...
