# %% [markdown]
# # URL Scraper

# %% [markdown]
# ### Crawl shopee url

# %%
"""
get_product_urls: để lấy file url.txt
get_product_info: lấy url từ toppic url kafka crawl nội dung tương ứng và lưu lại vào topic infor
"""
"""
./data/Thời Trang Nam/Quần Dài/base_url.txt ko tồn tại nên code dừng (do xuất hiện subsubcategory: Quần Âu) ==> Try, Except or làm tiếp với những mục đã có url.txt
"""
"""
crawl shopee
crawl lazada
clean data
kafka hdfs
visualize
"""

# %%
import sys
sys.path.append(r'C:\Users\Lenovo\Desktop\20251\BigData\code\BigData_nhom10')
from crawler.shopee_scraper import ShopeeScraper
scraper = ShopeeScraper(num_page_to_scrape=1, is_headless=False, data_dir=r'C:\Users\Lenovo\Desktop\20251\BigData\code\BigData_nhom10\data\shopee')
# # if login = run browser in the background
#scraper.get_main_page()
scraper.get_product_urls()
# Out:
# 2025-11-28 21:06:29,136 [INFO] undetected_chromedriver.patcher: patching driver executable C:\Users\Lenovo\appdata\roaming\undetected_chromedriver\undetected_chromedriver.exe
# 2025-11-28 21:06:33,318 [INFO] crawler.shopee_scraper: Scraping category: Máy Tính & Laptop/Gaming
# 2025-11-28 21:06:33,320 [INFO] crawler.shopee_scraper: Opening category page: https://shopee.vn/Gaming-cat.11035954.11036023
# 2025-11-28 21:06:38,981 [INFO] crawler.shopee_scraper: Scraping urls from page 1
# 2025-11-28 21:06:46,378 [INFO] crawler.shopee_scraper: Products not visible after 5s, retrying
# 2025-11-28 21:06:53,788 [INFO] crawler.shopee_scraper: Products not visible after 5s, retrying
# 2025-11-28 21:07:01,599 [INFO] crawler.shopee_scraper: Products not visible after 5s, retrying
# 2025-11-28 21:07:02,918 [INFO] crawler.shopee_scraper: Reached max pages for category Máy Tính & Laptop/Gaming
# 2025-11-28 21:07:02,938 [INFO] crawler.shopee_scraper: Scraping category: Máy Tính & Laptop/Khác
# 2025-11-28 21:07:02,941 [INFO] crawler.shopee_scraper: Opening category page: https://shopee.vn/Kh%C3%A1c-cat.11035954.11036016
# 2025-11-28 21:07:10,360 [INFO] crawler.shopee_scraper: Scraping urls from page 1
# 2025-11-28 21:07:15,853 [INFO] crawler.shopee_scraper: Found 40 products
# 2025-11-28 21:07:15,855 [INFO] crawler.shopee_scraper: Found 40 products with url
# 2025-11-28 21:07:15,856 [INFO] crawler.shopee_scraper: All product URLs loaded. Extracting...
# 2025-11-28 21:07:15,858 [INFO] crawler.shopee_scraper: Reached max pages for category Máy Tính & Laptop/Khác
# 2025-11-28 21:07:15,878 [INFO] crawler.shopee_scraper: Scraping category: Máy Tính & Laptop/Laptop
# 2025-11-28 21:07:15,880 [INFO] crawler.shopee_scraper: Opening category page: https://shopee.vn/Laptop-cat.11035954.11036015
# 2025-11-28 21:07:20,552 [INFO] crawler.shopee_scraper: Scraping urls from page 1
# 2025-11-28 21:07:28,335 [INFO] crawler.shopee_scraper: Products not visible after 5s, retrying
# 2025-11-28 21:07:35,888 [INFO] crawler.shopee_scraper: Products not visible after 5s, retrying
# 2025-11-28 21:07:43,502 [INFO] crawler.shopee_scraper: Products not visible after 5s, retrying
# 2025-11-28 21:08:30,720 [INFO] crawler.shopee_scraper: Reached max pages for category Máy Tính & Laptop/Máy Tính Bàn
# 2025-11-28 21:08:30,751 [INFO] crawler.shopee_scraper: Scraping category: Máy Tính & Laptop/Phụ Kiện Máy Tính
# 2025-11-28 21:08:30,753 [INFO] crawler.shopee_scraper: Opening category page: https://shopee.vn/Ph%E1%BB%A5-Ki%E1%BB%87n-M%C3%A1y-T%C3%ADnh-cat.11035954.11036000
# 2025-11-28 21:08:35,958 [INFO] crawler.shopee_scraper: Scraping urls from page 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 scraper = ShopeeScraper(num_page_to_scrape=1, is_headless=False, data_dir=r'C:\Users\Lenovo\Desktop\20251\BigData\code\BigData_nhom10\data\shopee')
#       5 # # if login = run browser in the background
#       6 #scraper.get_main_page()
# ----> 7 scraper.get_product_urls()
#
# File ~\Desktop\20251\BigData\code\BigData_nhom10\crawler\shopee_scraper.py:62, in ShopeeScraper.get_product_urls(self)
#      59 while True:
#      60     logger.info("Scraping urls from page " + str(counter))
# ---> 62     if prev_url == self.driver.current_url:
#      63         logger.info('Page identical to previous; reached last page')
#      64         break
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\undetected_chromedriver\__init__.py:806, in Chrome.__getattribute__(self, item)
#     804 def __getattribute__(self, item):
#     805     if not super().__getattribute__("debug"):
# --> 806         return super().__getattribute__(item)
#     807     else:
#     808         import inspect
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\selenium\webdriver\remote\webdriver.py:587, in WebDriver.current_url(self)
#     579 @property
#     580 def current_url(self) -> str:
#     581     """Gets the URL of the current page.
#     582
#     583     Example:
#     584     --------
#     585     >>> print(driver.current_url)
#     586     """
# --> 587     return self.execute(Command.GET_CURRENT_URL)["value"]
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\selenium\webdriver\remote\webdriver.py:455, in WebDriver.execute(self, driver_command, params)
#     452     elif "sessionId" not in params:
#     453         params["sessionId"] = self.session_id
# --> 455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
#     458     self.error_handler.check_response(response)
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\selenium\webdriver\remote\remote_connection.py:407, in RemoteConnection.execute(self, command, params)
#     405 trimmed = self._trim_large_entries(params)
#     406 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 407 return self._request(command_info[0], url, body=data)
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\selenium\webdriver\remote\remote_connection.py:431, in RemoteConnection._request(self, method, url, body)
#     428     body = None
#     430 if self._client_config.keep_alive:
# --> 431     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     432     statuscode = response.status
#     433 else:
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\urllib3\_request_methods.py:135, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     132     urlopen_kw["body"] = body
#     134 if method in self._encode_url_methods:
# --> 135     return self.request_encode_url(
#     136         method,
#     137         url,
#     138         fields=fields,  # type: ignore[arg-type]
#     139         headers=headers,
#     140         **urlopen_kw,
#     141     )
#     142 else:
#     143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\urllib3\_request_methods.py:182, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     179 if fields:
#     180     url += "?" + urlencode(fields)
# --> 182 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\urllib3\poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Lenovo\anaconda3\envs\bigdata\lib\socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # Info Scraper
