# %% [markdown]
# # URL Scraper

# %% [markdown]
# ### Crawl shopee url

# %%
from crawler.shopee_scraper import ShopeeScraper
scraper = ShopeeScraper(num_page_to_scrape=1, is_headless=False)
# # if login = run browser in the background
# scraper.get_main_page()

scraper.get_product_urls()

# %%
import undetected_chromedriver as uc

driver = uc.Chrome(version_main=142)  # ép về Chrome 142
driver.get("https://shopee.vn")

# %%
import json
path = r'C:\Users\Lenovo\Desktop\20251\BigData\code\BigData_nhom10\data\shopee\Thời Trang Nam\Áo\base_url.txt'
with open(path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
data
# Out:
# {'category': 'Thời Trang Nam/Áo',
#  'url': 'https://shopee.vn/%C3%81o-cat.11035567.11035592'}

# %%
type(data)
# Out:
# dict

# %% [markdown]
# # Info Scraper
